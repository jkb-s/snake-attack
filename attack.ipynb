# %%
from json import loads, dumps
from requests import get
from types import SimpleNamespace
from dataclasses import dataclass, field

# %%
def load_config(filename='config.json'):
    with open(filename, 'r') as file:
        return SimpleNamespace(**loads(file.read()))
    
def download_attack(url):
    response = get(url)
    if response.ok:
        return response.json()
    
def collect_objects(attack):
    collections = {}
    for obj in attack['objects']:
        tp = obj['type']
        if tp in collections:
            collections[tp].append(obj)
        else:
            collections.update({
                tp: [obj]
            })
    return collections

def get_technique_id(references):
    for ref in references:
        if ref['source_name'] == 'mitre-attack':
            return ref['external_id']
    return None

@dataclass
class ATechnique:
    name: str
    description: str = ""
    detection: str = ""
    data_sources: list = field(default_factory=list)
    platforms: list = field(default_factory=list)
    permissions_required: list = field(default_factory=list)
    defenses_bypassed: list = field(default_factory=list)
    id: str = ""
    tactics: list = field(default_factory=list)
    references: list = field(default_factory=list)
    ref: str = ""
    
@dataclass
class ARelation:
    source : str
    src: str
    target : str
    trg: str
    description: str
    type: str
    ref: str
    
@dataclass
class AGroup:
    name: str
    description: str = ""
    id: str = ""
    aliases: list = field(default_factory=list)
    ref: str = ""
    
def parse_techniques(objects):
    techniques = []
    for obj in collections['attack-pattern']:

        if 'revoked' in obj and obj['revoked']: continue

        id = get_technique_id(obj['external_references'])
        
        tactics = []
        for tac in obj['kill_chain_phases']:
            if tac['kill_chain_name'] == 'mitre-attack':
                tactics.append(
                    tac['phase_name']
                )

        defense = []
        if 'x_mitre_defense_bypassed' in obj and obj['x_mitre_defense_bypassed']:
            defense = obj['x_mitre_defense_bypassed']

        permissions = []
        if 'x_mitre_permissions_required' in obj and obj['x_mitre_permissions_required']:
            permissions = obj['x_mitre_permissions_required']

        tech = {
            'name': obj['name'],
            'platforms': obj['x_mitre_platforms'],
            'permissions_required': permissions,
            'defenses_bypassed': defense,
            'description': obj['description'],
            'detection': obj['x_mitre_detection'],
            'tactics': tactics,
            'id': id,
            'ref': obj['id']
        }

        atech = ATechnique(**tech)
        techniques.append(atech)
    return techniques

def parse_relations(relations):
    result_relations = []
    for rel in relations:
        data = {
            'source' : rel['source_ref'],
            'target' : rel['target_ref'],
            'description': rel.get('description', ''),
            'type': rel['relationship_type'],
            'ref': rel['id']
        }
        result_relations.append(
            ARelation(**data)
        )
    return result_relations

def parse_groups(groups_obj):
    groups = []
    for obj in groups_obj:
        #print(dumps(grp, indent=4))
        if 'revoked' in obj and obj['revoked']: continue

        id = get_technique_id(obj['external_references'])

        grp = {
                'name': obj['name'],
                'id': id,
                'ref': obj['id'],
                'description': obj['description'],
                'aliases': obj['aliases']
            }

        agrp = AGroup(**grp)
        groups.append(agrp)
    return groups

# %%
cfg = load_config()

# %%
attack = download_attack(cfg.attack_data)

# %%
collections = collect_objects(attack)

# %%
techniques_list = parse_techniques(collections['attack-pattern'])
techniques_id_index = {}
techniques = {}
for tech in techniques_list:
    techniques_id_index.update({
        tech.ref: tech.id
    })
    techniques.update({
        tech.id : tech
    })

# %%
relations_index = parse_relations(collections['relationship'])

# %%
groups_list = parse_groups(collections['intrusion-set'])
groups_id_index = {}
groups = {}
for grp in groups_list:
    groups_id_index.update({
        grp.ref : grp.id
    })
    groups.update({
        grp.id: grp
    })

# %%
relations_index = []

# %%
relations[0].source
# Out:
# 'course-of-action--beb45abb-11e8-4aef-9778-1f9ac249784f'

# %%
reltypes = set()
for rel in relations:
    if rel.type == 'revoked-by':
        print(rel)
    #reltypes.add(rel.type)
#reltypes
# Out:
# ARelation(source='malware--310f437b-29e7-4844-848c-7220868d074a', target='malware--b42378e0-f147-496f-992a-26a49705395b', description='', type='revoked-by', ref='relationship--87231371-e005-44ab-9b66-1954615f2a7e')
# ARelation(source='intrusion-set--9559ecaf-2e75-48a7-aee8-9974020bc772', target='intrusion-set--17862c7d-9e60-48a0-b48e-da4dc4c3f6b0', description='', type='revoked-by', ref='relationship--3680408d-e56e-4d68-a74d-2678093ed53f')
# ARelation(source='intrusion-set--68ba94ab-78b8-43e7-83e2-aed3466882c6', target='intrusion-set--4ca1929c-7d64-4aab-b849-badbfc0c760d', description='', type='revoked-by', ref='relationship--632ca9a0-a9f3-4b27-96e1-9fcb8bab11cb')
# ARelation(source='attack-pattern--52f3d5a6-8a0f-4f82-977e-750abf90d0b0', target='attack-pattern--0042a9f5-f053-4769-b3ef-9ad018dfa298', description='', type='revoked-by', ref='relationship--8be10d07-69bd-47ae-9dea-5918d1005699')
# ARelation(source='attack-pattern--c1a452f3-6499-4c12-b7e9-a6a0a102af76', target='attack-pattern--7007935a-a8a7-4c0b-bd98-4e85be8ed197', description='', type='revoked-by', ref='relationship--66932869-44bf-4422-b38c-69c9503d5db4')
# ARelation(source='attack-pattern--1c338d0f-a65e-4073-a5c1-c06878849f21', target='attack-pattern--b200542e-e877-4395-875b-cf1a44537ca4', description='', type='revoked-by', ref='relationship--bab08287-699f-438d-aa69-f72cbac37ba3')
# ARelation(source='attack-pattern--18d4ab39-12ed-4a16-9fdb-ae311bba4a0f', target='attack-pattern--dca670cf-eeec-438f-8185-fd959d9ef211', description='', type='revoked-by', ref='relationship--911d412e-9dd7-49ae-ab6a-a078b44a1791')
# ARelation(source='attack-pattern--2ba5aa71-9d15-4b22-b726-56af06d9ad2f', target='attack-pattern--c0dfe7b0-b873-4618-9ff8-53e31f70907f', description='', type='revoked-by', ref='relationship--94035326-619c-4307-ac07-5def29b85f59')
# ARelation(source='attack-pattern--0fff2797-19cb-41ea-a5f1-8a9303b8158e', target='attack-pattern--dfefe2ed-4389-4318-8762-f0272b350a1b', description='', type='revoked-by', ref='relationship--a3839408-eef4-4099-89c0-fc52ac55e650')
# ARelation(source='attack-pattern--dd901512-6e37-4155-943b-453e3777b125', target='attack-pattern--d10cbd34-42e3-45c0-84d2-535a09849584', description='', type='revoked-by', ref='relationship--57932175-4fe3-4ea1-b758-4cb6156273b2')
# ARelation(source='attack-pattern--9422fc14-1c43-410d-ab0f-a709b76c72dc', target='attack-pattern--9efb1ea7-c37b-4595-9640-b7680cd84279', description='', type='revoked-by', ref='relationship--330c49c0-a785-46f9-99c1-74322e26e20d')
# ARelation(source='attack-pattern--68c96494-1a50-403e-8844-69a6af278c68', target='attack-pattern--98034fef-d9fb-4667-8dc4-2eab6231724c', description='', type='revoked-by', ref='relationship--0b66c798-f1fc-4e2f-b3b4-433dde89a191')
# ARelation(source='attack-pattern--2892b9ee-ca9f-4723-b332-0dc6e843a8ae', target='attack-pattern--ce4b7013-640e-48a9-b501-d0025a95f4bf', description='', type='revoked-by', ref='relationship--cb273dc3-b4cf-4f74-9bf7-c9f5c0afcde2')
# ARelation(source='attack-pattern--e906ae4d-1d3a-4675-be23-22f7311c0da4', target='attack-pattern--910906dd-8c0a-475a-9cc1-5e029e2fad58', description='', type='revoked-by', ref='relationship--4c1c9ac8-e8b4-451c-991f-faf7e03d2e08')
# ARelation(source='attack-pattern--01df3350-ce05-4bdf-bdf8-0a919a66d4a8', target='attack-pattern--b63a34e8-0a61-4c97-a23b-bf8a2ed812e2', description='', type='revoked-by', ref='relationship--8e1cab5a-7a82-4116-8727-d77200f52419')
# ARelation(source='attack-pattern--b53dbcc6-147d-48bb-9df4-bcb8bb808ff6', target='attack-pattern--63220765-d418-44de-8fae-694b3912317d', description='', type='revoked-by', ref='relationship--88aa51c3-b020-4283-b325-798dad4134c4')
# ARelation(source='attack-pattern--04ef4356-8926-45e2-9441-634b6f3dcecb', target='attack-pattern--10ff21b9-5a01-4268-a1b5-3b55015f1847', description='', type='revoked-by', ref='relationship--afcc8362-e43f-4be9-8fe4-c6c2ce4590b1')
# ARelation(source='attack-pattern--bb0e0cb5-f3e4-4118-a4cb-6bf13bfbc9f2', target='attack-pattern--f63fe421-b1d1-45c0-b8a7-02cd16ff2bed', description='', type='revoked-by', ref='relationship--2c2fc4fc-1c2d-4a97-871e-fe65ee8c9d7c')
# ARelation(source='attack-pattern--9b99b83a-1aac-4e29-b975-b374950551a3', target='attack-pattern--70e52b04-2a0c-4cea-9d18-7149f1df9dc5', description='', type='revoked-by', ref='relationship--4fd63ec9-e2ad-4473-b9ed-90d7dfe378e8')
# ARelation(source='attack-pattern--4bf5845d-a814-4490-bc5c-ccdee6043025', target='attack-pattern--7d57b371-10c2-45e5-b3cc-83a8fb380e4c', description='', type='revoked-by', ref='relationship--ecf3d7ec-a8f9-435a-9c09-6d264f319728')
# ARelation(source='attack-pattern--317fefa6-46c7-4062-adb6-2008cf6bcb41', target='attack-pattern--cc89ecbd-3d33-4a41-bcca-001e702d18fd', description='', type='revoked-by', ref='relationship--ef087ae8-5b2c-4cc9-99f0-c3f9550fc94e')
# ARelation(source='attack-pattern--7c93aa74-4bc0-4a9e-90ea-f25f86301566', target='attack-pattern--42fe883a-21ea-4cfb-b94a-78b6476dcc83', description='', type='revoked-by', ref='relationship--d15d091e-a720-4fb5-acfc-0982e23fe185')
# ARelation(source='attack-pattern--62166220-e498-410f-a90a-19d4339d4e99', target='attack-pattern--6d4a7fb3-5a24-42be-ae61-6728a2b581f6', description='', type='revoked-by', ref='relationship--22c5d62b-40cd-4dce-9b6d-7836b67ee7f5')
# ARelation(source='attack-pattern--723e3a2b-ca0d-4daa-ada8-82ea35d3733a', target='attack-pattern--0f2c410d-d740-4ed9-abb1-b8f4a7faf6c3', description='', type='revoked-by', ref='relationship--d3cbff81-245f-4025-a24a-f9ca5e006fb4')
# ARelation(source='attack-pattern--d376668f-b208-42de-b1f5-fdfe0ad4b753', target='attack-pattern--9c45eaa3-8604-4780-8988-b5074dbb9ecd', description='', type='revoked-by', ref='relationship--8bcaac7c-46c8-459a-a55c-b1e218c62cfc')
# ARelation(source='attack-pattern--52d40641-c480-4ad5-81a3-c80ccaddf82d', target='attack-pattern--b8cfed42-6a8a-4989-ad72-541af74475ec', description='', type='revoked-by', ref='relationship--da0d2c02-a213-4815-a653-1e9b0a1b2841')
# ARelation(source='attack-pattern--dce31a00-1e90-4655-b0f9-e2e71a748a87', target='attack-pattern--61afc315-860c-4364-825d-0d62b2e91edc', description='', type='revoked-by', ref='relationship--afb0685e-2c5c-4eec-9205-b1afdab4eda5')
# ARelation(source='attack-pattern--514ede4c-78b3-4d78-a38b-daddf6217a79', target='attack-pattern--6836813e-8ec8-4375-b459-abb388cb1a35', description='', type='revoked-by', ref='relationship--bab689ff-c89e-452f-bca6-a01078ae406e')
# ARelation(source='attack-pattern--6c174520-beea-43d9-aac6-28fb77f3e446', target='attack-pattern--5095a853-299c-4876-abd7-ac0050fb5462', description='', type='revoked-by', ref='relationship--21f9567c-18c5-41b2-9b57-bb2c039b5293')
# ARelation(source='attack-pattern--6be14413-578e-46c1-8304-310762b3ecd5', target='attack-pattern--a1b52199-c8c5-438a-9ded-656f1d0888c6', description='', type='revoked-by', ref='relationship--50dea2f5-86ac-4786-b118-d67da0fa1a03')
# ARelation(source='attack-pattern--6a3be63a-64c5-4678-a036-03ff8fc35300', target='attack-pattern--e5cc9e7a-e61a-46a1-b869-55fb6eab058e', description='', type='revoked-by', ref='relationship--6cd07a3b-18d3-40ec-ab3d-cd4ae952609c')
# ARelation(source='attack-pattern--6e6845c2-347a-4a6f-a2d1-b74a18ebd352', target='attack-pattern--f0589bc3-a6ae-425a-a3d5-5659bfee07f4', description='', type='revoked-by', ref='relationship--8dfa86a7-1b39-4457-bd41-c1ff62685711')
# ARelation(source='attack-pattern--970cdb5c-02fb-4c38-b17e-d6327cf3c810', target='attack-pattern--4ab929c6-ee2d-4fb5-aab4-b14be2ed7179', description='', type='revoked-by', ref='relationship--fe8358f5-ead6-4ae7-a88c-831dda8ab123')
# ARelation(source='attack-pattern--1f47e2fd-fa77-4f2f-88ee-e85df308f125', target='attack-pattern--43881e51-ac74-445b-b4c6-f9f9e9bf23fe', description='', type='revoked-by', ref='relationship--39221b72-9f98-4434-9de6-139c154b8705')
# ARelation(source='attack-pattern--27960489-4e7f-461d-a62a-f5c0cb521e4a', target='attack-pattern--f005e783-57d4-4837-88ad-dbe7faee1c51', description='', type='revoked-by', ref='relationship--162772ee-960e-4b14-9c90-0d86ef3e5cf8')
# ARelation(source='attack-pattern--c23b740b-a42b-47a1-aec2-9d48ddd547ff', target='attack-pattern--e624264c-033a-424d-9fd7-fc9c3bbdb03e', description='', type='revoked-by', ref='relationship--f67134f6-7f34-4b8a-89ef-9ecd6d9ca191')
# ARelation(source='attack-pattern--a257ed11-ff3b-4216-8c9d-3938ef57064c', target='attack-pattern--7b211ac6-c815-4189-93a9-ab415deca926', description='', type='revoked-by', ref='relationship--f4c17470-c5c0-4680-ad4a-5efae63b0be6')
# ARelation(source='attack-pattern--c5e31fb5-fcbd-48a4-af8c-5a6ed5b932e5', target='attack-pattern--c3c8c916-2f3c-4e71-94b2-240bdfc996f0', description='', type='revoked-by', ref='relationship--1ca95660-87c1-42f9-bb5d-7435f7999c88')
# ARelation(source='attack-pattern--d3046a90-580c-4004-8208-66915bc29830', target='attack-pattern--3aef9463-9a7a-43ba-8957-a867e07c1e6a', description='', type='revoked-by', ref='relationship--ea774e46-3dcb-4cda-ad99-a012ad8fbb58')
# ARelation(source='attack-pattern--56fca983-1cf1-4fd1-bda0-5e170a37ab59', target='attack-pattern--d63a3fb8-9452-4e9d-a60a-54be68d5998c', description='', type='revoked-by', ref='relationship--f6514d17-d599-4a45-93b2-a80b4aa39dde')
# ARelation(source='attack-pattern--e7eab98d-ae11-4491-bd28-a53ba875865a', target='attack-pattern--a750a9f6-0bde-4bb3-9aae-1e2786e9780c', description='', type='revoked-by', ref='relationship--ba5e1994-4732-44a0-a266-452ca526df5a')
# ARelation(source='attack-pattern--7d6f590f-544b-45b4-9a42-e0805f342af3', target='attack-pattern--4cbc6a62-9e34-4f94-8a19-5c1a11392a49', description='', type='revoked-by', ref='relationship--7083356e-b0a6-4fff-ac50-6d0ea2a841bc')
# ARelation(source='attack-pattern--d21a2069-23d5-4043-ad6d-64f6b644cb1a', target='attack-pattern--a6937325-9321-4e2e-bb2b-3ed2d40b2a9d', description='', type='revoked-by', ref='relationship--7a35d985-17ae-429a-b828-08d34e92002f')
# ARelation(source='attack-pattern--8df54627-376c-487c-a09c-7d2b5620f56e', target='attack-pattern--4ff5d6a8-c062-4c68-a778-36fc5edd564f', description='', type='revoked-by', ref='relationship--e8b07bb0-a0d3-49b2-a6c4-f546c50cdb64')
# ARelation(source='attack-pattern--f792d02f-813d-402b-86a5-ab98cb391d3b', target='attack-pattern--2cd950a6-16c4-404a-aa01-044322395107', description='', type='revoked-by', ref='relationship--2067eae0-bab7-4737-a5ad-9c4c439d6a2c')
# ARelation(source='attack-pattern--a127c32c-cbb0-4f9d-be07-881a792408ec', target='attack-pattern--840a987a-99bd-4a80-a5c9-0cb2baa6cade', description='', type='revoked-by', ref='relationship--8d5b2fe4-24c5-4a07-a1b0-8d1bac21af69')
# ARelation(source='attack-pattern--215190a9-9f02-4e83-bb5f-e0589965a302', target='attack-pattern--c48a67ee-b657-45c1-91bf-6cdbe27205f8', description='', type='revoked-by', ref='relationship--696fe03b-95f6-400e-8bea-d9b16a2fd1b2')
# ARelation(source='attack-pattern--68f7e3a1-f09f-4164-9a62-16b648a0dd5a', target='attack-pattern--b97f1d35-4249-4486-a6b5-ee60ccf24fab', description='', type='revoked-by', ref='relationship--bbf33c27-569c-4005-b047-63b8ec4e6a22')
# ARelation(source='attack-pattern--62b8c999-dcc0-4755-bd69-09442d9359f5', target='attack-pattern--045d0922-2310-4e60-b5e4-3302302cb3c5', description='', type='revoked-by', ref='relationship--4d7a9d82-1400-42bd-982a-3e0e4d9396fa')
# ARelation(source='attack-pattern--ba8e391f-14b5-496f-81f2-2d5ecd646c1c', target='attack-pattern--837f9164-50af-4ac0-8219-379d8a74cefc', description='', type='revoked-by', ref='relationship--25ca7826-9f46-45e4-97e8-c942f9a2611d')
# ARelation(source='attack-pattern--2edd9d6a-5674-4326-a600-ba56de467286', target='attack-pattern--341e222a-a6e3-4f6f-b69c-831d792b1580', description='', type='revoked-by', ref='relationship--aee0e283-5bbd-4332-af46-f477d3ce38d6')
# ARelation(source='attack-pattern--44dca04b-808d-46ca-b25f-d85236d4b9f8', target='attack-pattern--8187bd2a-866f-4457-9009-86b0ddedffa3', description='', type='revoked-by', ref='relationship--ed9b40ef-51ff-4263-a99e-5c95bae3e17d')
# ARelation(source='attack-pattern--6ff403bc-93e3-48be-8687-e102fdba8c88', target='attack-pattern--deb98323-e13f-4b0c-8d94-175379069062', description='', type='revoked-by', ref='relationship--3d131e85-111d-4df2-ba93-274acba5146f')
# ARelation(source='attack-pattern--519630c5-f03f-4882-825c-3af924935817', target='attack-pattern--5bfccc3f-2326-4112-86cc-c1ece9d8a2b5', description='', type='revoked-by', ref='relationship--3e2ca5c5-2e5c-4e8a-98c4-0455cea56a88')
# ARelation(source='attack-pattern--6fb6408c-0db3-41d9-a3a1-a32e5f16454e', target='attack-pattern--31a0a2ac-c67c-4a7e-b9ed-6a96477d4e8e', description='', type='revoked-by', ref='relationship--da53b0a3-6b35-46af-b47c-f2e9f22ec683')
# ARelation(source='attack-pattern--1b84d551-6de8-4b96-9930-d177677c3b1d', target='attack-pattern--32901740-b42c-4fdd-bc02-345b5dc57082', description='', type='revoked-by', ref='relationship--ea022ac4-0c8b-4ad0-a160-14640654df2e')
# ARelation(source='attack-pattern--72b5ef57-325c-411b-93ca-a3ca6fa17e31', target='attack-pattern--543fceb5-cb92-40cb-aacf-6913d4db58bc', description='', type='revoked-by', ref='relationship--81ccd9e7-54a7-4b1c-8c69-7c238cac38f9')
# ARelation(source='attack-pattern--ca1a3f50-5ebd-41f8-8320-2c7d6a6e88be', target='attack-pattern--120d5519-3098-4e1c-9191-2aa61232f073', description='', type='revoked-by', ref='relationship--4a96d822-28cc-4820-8fb0-d7a049547bc9')
# ARelation(source='attack-pattern--c0df6533-30ee-4a4a-9c6d-17af5abdf0b2', target='attack-pattern--6831414d-bb70-42b7-8030-d4e06b2660c9', description='', type='revoked-by', ref='relationship--b7064aad-995c-450f-b43d-f4bd2362d401')
# ARelation(source='attack-pattern--2169ba87-1146-4fc7-a118-12b72251db7e', target='attack-pattern--1365fe3b-0f50-455d-b4da-266ce31c23b0', description='', type='revoked-by', ref='relationship--fdb054f1-0446-4af0-b11c-790fbf352014')
# ARelation(source='attack-pattern--9e80ddfb-ce32-4961-a778-ca6a10cfae72', target='attack-pattern--1365fe3b-0f50-455d-b4da-266ce31c23b0', description='', type='revoked-by', ref='relationship--126f9334-8b0c-4948-a495-07e2b5a7744a')
# ARelation(source='attack-pattern--101c3a64-9ba5-46c9-b573-5c501053cbca', target='attack-pattern--b84903f0-c7d5-435d-a69e-de47cc3578c0', description='', type='revoked-by', ref='relationship--6ac1f40a-5fae-4d51-b357-0f57eec77a96')
# ARelation(source='attack-pattern--e2907cea-4b43-4ed7-a570-0fdf0fbeea00', target='attack-pattern--e51137a5-1cdc-499e-911a-abaedaa5ac86', description='', type='revoked-by', ref='relationship--be8cf250-e9ce-41a2-beb8-888795f6fc04')
# ARelation(source='attack-pattern--51dea151-0898-4a45-967c-3ebee0420484', target='attack-pattern--eb062747-2193-45de-8fa2-e62549c37ddf', description='', type='revoked-by', ref='relationship--fd31c763-8e36-4f6f-9238-fed081b524b3')
# ARelation(source='attack-pattern--ffe742ed-9100-4686-9e00-c331da544787', target='attack-pattern--4f9ca633-15c5-463c-9724-bdcd54fde541', description='', type='revoked-by', ref='relationship--bcdb80d6-8ae4-4283-8abd-e933b498be13')
# ARelation(source='attack-pattern--c3bce4f4-9795-46c6-976e-8676300bbc39', target='attack-pattern--60d0c01d-e2bf-49dd-a453-f8a9c9fa6f65', description='', type='revoked-by', ref='relationship--a8689b2d-917b-432d-97ea-7b06a2da0bee')
# ARelation(source='attack-pattern--1c2fd73a-e634-44ed-b1b5-9e7cf7404e9f', target='attack-pattern--19bf235b-8620-4997-b5b4-94e0659ed7c3', description='', type='revoked-by', ref='relationship--4c998857-39b2-4c8c-a11c-089c469f7b33')
# ARelation(source='attack-pattern--b8c5c9dd-a662-479d-9428-ae745872537c', target='attack-pattern--3731fbcd-0e43-47ae-ae6c-d15e510f0d42', description='', type='revoked-by', ref='relationship--e2a6a14d-87d3-4a8b-966f-fb3c1fab6e87')
# ARelation(source='attack-pattern--0dbf5f1b-a560-4d51-ac1b-d70caab3e1f0', target='attack-pattern--650c784b-7504-4df7-ab2c-4ea882384d1e', description='', type='revoked-by', ref='relationship--8d7957af-a314-4e12-bde6-6148e234ff58')
# ARelation(source='attack-pattern--b39d03cb-7b98-41c4-a878-c40c1a913dc0', target='attack-pattern--f2877f7f-9a4c-4251-879f-1224e3006bee', description='', type='revoked-by', ref='relationship--3e24f01c-3af8-4dde-9200-4f69fecb3156')
# ARelation(source='attack-pattern--91ce1ede-107f-4d8b-bf4c-735e8789c94b', target='attack-pattern--a2029942-0a85-4947-b23c-ca434698171d', description='', type='revoked-by', ref='relationship--63097f33-1259-4120-8fb0-3a1cf1b6d4ec')
# ARelation(source='attack-pattern--66f73398-8394-4711-85e5-34c8540b22a5', target='attack-pattern--f5946b5e-9408-485f-a7f7-b5efc88909b6', description='', type='revoked-by', ref='relationship--fb82f6d3-0e6b-4fa5-a54a-f7deb28f8324')
# ARelation(source='attack-pattern--9e09ddb2-1746-4448-9cad-7f8b41777d6d', target='attack-pattern--1eaebf46-e361-4437-bc23-d5d65a3b92e3', description='', type='revoked-by', ref='relationship--3871b3d6-9b62-4f20-af9f-8317b263b5a8')
# ARelation(source='attack-pattern--2715c335-1bf2-4efe-9f18-0691317ff83b', target='attack-pattern--1a80d097-54df-41d8-9d33-34e755ec5e72', description='', type='revoked-by', ref='relationship--844a7c42-0d65-4e10-b438-e7aad091e443')
# ARelation(source='attack-pattern--4579d9c9-d5b9-45e0-9848-0104637b579f', target='attack-pattern--58a3e6aa-4453-4cc8-a51f-4befe80b31a8', description='', type='revoked-by', ref='relationship--8ccf5cfb-df98-44e0-afb7-6e2d6c699944')
# ARelation(source='attack-pattern--56ff457d-5e39-492b-974c-dfd2b8603ffe', target='attack-pattern--60b508a1-6a5e-46b1-821a-9f7b78752abf', description='', type='revoked-by', ref='relationship--62959831-1f76-4274-b462-731fcffd164d')
# ARelation(source='attack-pattern--128c55d3-aeba-469f-bd3e-c8996ab4112a', target='attack-pattern--47f2d673-ca62-47e9-929b-1b0be9657611', description='', type='revoked-by', ref='relationship--52cfec4e-9a4f-47b4-ba8a-fc95e034ac1e')
# ARelation(source='attack-pattern--9ddc2534-e91c-4dab-a8f6-43dab81e8142', target='attack-pattern--93591901-3172-4e94-abf8-6034ab26f44a', description='', type='revoked-by', ref='relationship--206ded49-56fc-4c86-ab43-f4d45f5c343c')
# ARelation(source='attack-pattern--1df0326d-2fbc-4d08-a16b-48365f1e742d', target='attack-pattern--b7dc639b-24cd-482d-a7f1-8897eda21023', description='', type='revoked-by', ref='relationship--9d925db0-de86-42c8-b69e-8d89e40328ed')
# ARelation(source='attack-pattern--b82f7d37-b826-4ec9-9391-8e121c78aed7', target='attack-pattern--fb640c43-aa6b-431e-a961-a279010424ac', description='', type='revoked-by', ref='relationship--312cffa6-cdda-48cd-a003-dfd7183355c3')
# ARelation(source='attack-pattern--2e114e45-2c50-404c-804a-3af9564d240e', target='attack-pattern--0af0ca99-357d-4ba1-805f-674fdfb7bef9', description='', type='revoked-by', ref='relationship--ef02e21a-5ccd-4a69-a735-b9eba6f08b91')
# ARelation(source='attack-pattern--2e0dd10b-676d-4964-acd0-8a404c92b044', target='attack-pattern--ac08589e-ee59-4935-8667-d845e38fe579', description='', type='revoked-by', ref='relationship--c8019115-38f0-4949-b7c6-331898b2cc83')
# ARelation(source='attack-pattern--086952c4-5b90-4185-b573-02bad8e11953', target='attack-pattern--8f504411-cb96-4dac-a537-8d2bb7679c59', description='', type='revoked-by', ref='relationship--7aaab0ef-69b8-4b34-98bc-8a83ff654884')
# ARelation(source='attack-pattern--d519cfd5-f3a8-43a9-a846-ed0bb40672b1', target='attack-pattern--c615231b-f253-4f58-9d47-d5b4cbdb6839', description='', type='revoked-by', ref='relationship--7799861e-ea03-4574-9170-e4b3ba241cc5')
# ARelation(source='attack-pattern--241814ae-de3f-4656-b49e-f9a80764d4b7', target='attack-pattern--cba37adb-d6fb-4610-b069-dd04c0643384', description='', type='revoked-by', ref='relationship--496b2565-c0fb-4de7-8446-e8125bfa4f28')
# ARelation(source='attack-pattern--c1b11bf7-c68e-4fbf-a95b-28efbe7953bb', target='attack-pattern--4d2a5b3e-340d-4600-9123-309dd63c9bf8', description='', type='revoked-by', ref='relationship--22e606f5-4130-4de8-984b-cfabcf5fc21c')
# ARelation(source='attack-pattern--0bf78622-e8d2-41da-a857-731472d61a92', target='attack-pattern--1cfcb312-b8d7-47a4-b560-4b16cc677292', description='', type='revoked-by', ref='relationship--fcdcb31d-2e52-43f4-a883-c60325a13075')
# ARelation(source='attack-pattern--cc1e737c-236c-4e3b-83ba-32039a626ef8', target='attack-pattern--d0613359-5781-4fd2-b5be-c269270be1f6', description='', type='revoked-by', ref='relationship--2ba17ab3-f9ae-4052-a7c7-b6d0e10b8b96')
# ARelation(source='attack-pattern--ca205a36-c1ad-488b-aa6c-ab34bdd3a36b', target='attack-pattern--32ad5c86-2bcf-47d8-8fdc-d7f3d79a7490', description='', type='revoked-by', ref='relationship--fd3ba994-75a3-4b1e-bfea-8e36b9a07015')
# ARelation(source='attack-pattern--6aac77c4-eaf2-4366-8c13-ce50ab951f38', target='attack-pattern--2e34237d-8574-43f6-aace-ae2915de8597', description='', type='revoked-by', ref='relationship--3ffda000-9e1b-4f63-8cc4-7b31feeb0b12')
# ARelation(source='attack-pattern--20138b9d-1aac-4a26-8654-a36b6bbf2bba', target='attack-pattern--2b742742-28c3-4e1b-bab7-8350d6300fa7', description='', type='revoked-by', ref='relationship--afaa6cd5-ff04-479a-a3e6-c25a4154be4b')
# ARelation(source='attack-pattern--d3df754e-997b-4cf9-97d4-70feb3120847', target='attack-pattern--f6ad61ee-65f3-4bd0-a3f5-2f0accb36317', description='', type='revoked-by', ref='relationship--5bde01dc-6c27-4494-a3eb-7a7d98982477')
# ARelation(source='attack-pattern--edbe24e9-aec4-4994-ac75-6a6bc7f1ddd0', target='attack-pattern--232a7e42-cd6e-4902-8fe9-2960f529dd4d', description='', type='revoked-by', ref='relationship--f823cffe-1f48-499e-a7b9-58f12e0b95b4')
# ARelation(source='attack-pattern--f4882e23-8aa7-4b12-b28a-b349c12ee9e0', target='attack-pattern--970a3432-3237-47ad-bcca-7d8cbb217736', description='', type='revoked-by', ref='relationship--d948a3b2-4873-4175-be18-ddef1c20347d')
# ARelation(source='attack-pattern--5ad95aaa-49c1-4784-821d-2e83f47b079b', target='attack-pattern--37b11151-1776-4f8f-b328-30939fbf2ceb', description='', type='revoked-by', ref='relationship--676011dc-7c68-40ac-aec5-cb8d71e66a27')
# ARelation(source='attack-pattern--53bfc8bf-8f76-4cd7-8958-49a884ddb3ee', target='attack-pattern--810aa4ad-61c9-49cb-993f-daa06199421d', description='', type='revoked-by', ref='relationship--68a528b5-ddc5-431a-9d63-eb2a6ce03559')
# ARelation(source='attack-pattern--f44731de-ea9f-406d-9b83-30ecbb9b4392', target='attack-pattern--f1951e8a-500e-4a26-8803-76d95c4554b4', description='', type='revoked-by', ref='relationship--8f5086fd-1cae-4f43-8a23-e47ace0620db')
# ARelation(source='attack-pattern--dc27c2ec-c5f9-4228-ba57-d67b590bda93', target='attack-pattern--ec8fc7e2-b356-455c-8db5-2e37be158e7d', description='', type='revoked-by', ref='relationship--12043603-b490-41fc-84ed-99e70ca4876c')
# ARelation(source='attack-pattern--ce73ea43-8e77-47ba-9c11-5e9c9c58b9ff', target='attack-pattern--8c4aef43-48d5-49aa-b2af-c0cd58d30c3d', description='', type='revoked-by', ref='relationship--0ad2b49a-d35f-464c-a3c6-f9342977fefc')
# ARelation(source='attack-pattern--04ee0cb7-dac3-4c6c-9387-4c6aa096f4cf', target='attack-pattern--cbb66055-0325-4111-aca0-40547b6ad5b0', description='', type='revoked-by', ref='relationship--03a3226b-0b28-49a9-860f-a8c13ffbe00d')
# ARelation(source='attack-pattern--f2d44246-91f1-478a-b6c8-1227e0ca109d', target='attack-pattern--f2857333-11d4-45bf-b064-2c28d8525be5', description='', type='revoked-by', ref='relationship--19ae270d-686b-4c13-94c9-ade20e57556c')
# ARelation(source='attack-pattern--c848fcf7-6b62-4bde-8216-b6c157d48da0', target='attack-pattern--b18eae87-b469-4e14-b454-b171b416bc18', description='', type='revoked-by', ref='relationship--8933e64e-6a0d-4cd1-8cab-514424f22410')
# ARelation(source='attack-pattern--7d751199-05fa-4a72-920f-85df4506c76c', target='attack-pattern--a782ebe2-daba-42c7-bc82-e8e9d923162d', description='', type='revoked-by', ref='relationship--cd958638-07f3-4c7f-acf3-404195d3a325')
# ARelation(source='attack-pattern--1ce03c65-5946-4ac9-9d4d-66db87e024bd', target='attack-pattern--ca9d3402-ada3-484d-876a-d717bd6e05f2', description='', type='revoked-by', ref='relationship--0f2d1c8b-4fb7-41e7-8def-36123060e5ae')
# ARelation(source='attack-pattern--cf7b3a06-8b42-4c33-bbe9-012120027925', target='attack-pattern--c726e0a2-a57a-4b7b-a973-d0f013246617', description='', type='revoked-by', ref='relationship--f4dc8dba-ec23-4d49-a736-c5b1edf5e53e')
# ARelation(source='attack-pattern--62dfd1ca-52d5-483c-a84b-d6e80bf94b7b', target='attack-pattern--2959d63f-73fd-46a1-abd2-109d7dcede32', description='', type='revoked-by', ref='relationship--2b33ca7e-3b33-44db-9479-1bba85e76902')
# ARelation(source='attack-pattern--06780952-177c-4247-b978-79c357fb311f', target='attack-pattern--6747daa2-3533-4e78-8fb8-446ebb86448a', description='', type='revoked-by', ref='relationship--830006c6-3ea6-4680-a8f5-42fad83d5433')
# ARelation(source='attack-pattern--478aa214-2ca7-4ec0-9978-18798e514790', target='attack-pattern--2959d63f-73fd-46a1-abd2-109d7dcede32', description='', type='revoked-by', ref='relationship--5fa955eb-63da-4281-8904-03f6c04c9d8d')
# ARelation(source='attack-pattern--e99ec083-abdd-48de-ad87-4dbf6f8ba2a4', target='attack-pattern--573ad264-1371-4ae0-8482-d2673b719dba', description='', type='revoked-by', ref='relationship--5b37828a-67db-4d36-831f-be0a6c3003b6')
# ARelation(source='attack-pattern--46944654-fcc1-4f63-9dad-628102376586', target='attack-pattern--2fee9321-3e71-4cf4-af24-d4d40d355b34', description='', type='revoked-by', ref='relationship--38b33f88-bc7e-4376-891d-51e7a0404174')
# ARelation(source='attack-pattern--aa8bfbc9-78dc-41a4-a03b-7453e0fdccda', target='attack-pattern--fc742192-19e3-466c-9eb5-964a97b29490', description='', type='revoked-by', ref='relationship--62248cd9-d997-468e-8606-6fa0c36330f4')
# ARelation(source='attack-pattern--0ca7beef-9bbc-4e35-97cf-437384ddce6a', target='attack-pattern--9e8b28c9-35fe-48ac-a14d-e6cc032dcbcd', description='', type='revoked-by', ref='relationship--484a1a7a-9e4e-4815-85bd-82a7ea607f2d')
# ARelation(source='attack-pattern--39a130e1-6ab7-434a-8bd2-418e7d9d6427', target='attack-pattern--17cc750b-e95b-4d7d-9dde-49e0de24148c', description='', type='revoked-by', ref='relationship--618cfee6-a12a-4e17-b66b-cbd965a08357')
# ARelation(source='attack-pattern--c0a384a4-9a25-40e1-97b6-458388474bc8', target='attack-pattern--35dd844a-b219-4e2b-a6bb-efa9a75995a9', description='', type='revoked-by', ref='relationship--5c3c9a95-98ee-4f60-8291-c4c34347adb6')
# ARelation(source='attack-pattern--6a5848a8-6201-4a2c-8a6a-ca5af8c6f3df', target='attack-pattern--74d2a63f-3c7b-4852-92da-02d8fbab16da', description='', type='revoked-by', ref='relationship--46c31831-b5b7-4e33-a9a2-2fb2f4ab29f8')
# ARelation(source='attack-pattern--36675cd3-fe00-454c-8516-aebecacbe9d9', target='attack-pattern--6747daa2-3533-4e78-8fb8-446ebb86448a', description='', type='revoked-by', ref='relationship--f6dab4c6-6f2e-4038-827f-16aa1fd7d8e9')
# ARelation(source='attack-pattern--c16e5409-ee53-4d79-afdc-4099dc9292df', target='attack-pattern--5d0d3609-d06d-49e1-b9c9-b544e0c618cb', description='', type='revoked-by', ref='relationship--45320c5e-4aae-4e45-9aac-23f863957056')
# ARelation(source='attack-pattern--b2001907-166b-4d71-bb3c-9d26c871de09', target='attack-pattern--e64c62cf-9cd7-4a14-94ec-cdaac43ab44b', description='', type='revoked-by', ref='relationship--d4895c50-334c-4d8b-b329-8613de602fa4')
# ARelation(source='attack-pattern--00d0b012-8a03-410e-95de-5826bf542de6', target='attack-pattern--b0533c6e-8fea-4788-874f-b799cacc4b92', description='', type='revoked-by', ref='relationship--cb4015bf-e7a4-4b26-8816-1f7a996adf4f')
# ARelation(source='attack-pattern--9b52fca7-1a36-4da0-b62d-da5bd83b4d69', target='attack-pattern--bc0f5e80-91c0-4e04-9fbb-e4e332c85dae', description='', type='revoked-by', ref='relationship--79cf4e4a-aa04-4414-85a8-17cc6f0cad18')
# ARelation(source='attack-pattern--f72eb8a8-cd4c-461d-a814-3f862befbf00', target='attack-pattern--c21d5a77-d422-4a69-acd7-2c53c1faa34b', description='', type='revoked-by', ref='relationship--e4a43af9-e8f0-42cf-a707-b2393efb44f5')
# ARelation(source='attack-pattern--54456690-84de-4538-9101-643e26437e09', target='attack-pattern--118f61a5-eb3e-4fb6-931f-2096647f4ecd', description='', type='revoked-by', ref='relationship--d466f2a4-4d31-4343-b56f-f2d132dc1d3e')
# ARelation(source='attack-pattern--02fefddc-fb1b-423f-a76b-7552dd211d4d', target='attack-pattern--1b7b1806-7746-41a1-a35d-e48dae25ddba', description='', type='revoked-by', ref='relationship--0e4407b6-fa67-48a7-97c5-f0bff5112912')
# ARelation(source='attack-pattern--4b74a1d4-b0e9-4ef1-93f1-14ecc6e2f5b5', target='attack-pattern--b8902400-e6c5-4ba2-95aa-2d35b442b118', description='', type='revoked-by', ref='relationship--76fd5c9b-2158-4372-85b6-a6961b68aaed')
# ARelation(source='attack-pattern--327f3cc5-eea1-42d4-a6cd-ed34b7ce8f61', target='attack-pattern--92a78814-b191-47ca-909c-1ccfe3777414', description='', type='revoked-by', ref='relationship--b8d85cbc-a92e-4921-94bc-defa75becbf3')
# ARelation(source='attack-pattern--428ca9f8-0e33-442a-be87-f869cb4cf73e', target='attack-pattern--b8902400-e6c5-4ba2-95aa-2d35b442b118', description='', type='revoked-by', ref='relationship--de56c26f-ea38-4e6e-a933-fdf4cd1932dd')
# ARelation(source='attack-pattern--b9f5dbe2-4c55-4fc5-af2e-d42c1d182ec4', target='attack-pattern--53ac20cd-aca3-406e-9aa0-9fc7fdc60a5a', description='', type='revoked-by', ref='relationship--b4bff800-f33a-472c-9000-23fa217aac69')
# ARelation(source='attack-pattern--d54416bd-0803-41ca-870a-ce1af7c05638', target='attack-pattern--53ac20cd-aca3-406e-9aa0-9fc7fdc60a5a', description='', type='revoked-by', ref='relationship--96f5f245-a67b-4e3d-8d3f-ef2a7719a3fd')
# ARelation(source='attack-pattern--6856ddd6-2df3-4379-8b87-284603c189c3', target='attack-pattern--16ab6452-c3c1-497c-a47d-206018ca1ada', description='', type='revoked-by', ref='relationship--e367aefb-5784-4fd8-85ac-56afa3f9e504')
# ARelation(source='attack-pattern--3b3cbbe0-6ed3-4334-b543-3ddfd8c5642d', target='attack-pattern--b8902400-e6c5-4ba2-95aa-2d35b442b118', description='', type='revoked-by', ref='relationship--5bda6db3-c05b-4733-8935-a11dfc30c64d')
# ARelation(source='attack-pattern--3b4121aa-fc8b-40c8-ac4f-afcb5838b72c', target='attack-pattern--0708ae90-d0eb-4938-9a76-d0fc94f6eec1', description='', type='revoked-by', ref='relationship--a03f53c2-4445-4ca5-ab2a-624afcbb9ea4')
# ARelation(source='attack-pattern--10d5f3b7-6be6-4da5-9a77-0f1e2bbfcc44', target='attack-pattern--791481f8-e96a-41be-b089-a088763083d4', description='', type='revoked-by', ref='relationship--0536e9fb-2b02-43e4-b3e4-1191ed4b526d')
# ARelation(source='intrusion-set--dc5e2999-ca1a-47d4-8d12-a6984b138a1b', target='intrusion-set--899ce53f-13a0-479b-a0e4-67d46e241542', description='', type='revoked-by', ref='relationship--958ceb5f-7b5d-4f7f-94e3-814c2d0375d2')
# ARelation(source='intrusion-set--7a0d4c09-dfe7-4fa2-965a-1a0e42fedd70', target='intrusion-set--0ec2f388-bf0f-4b5c-97b1-fc736d26c25f', description='', type='revoked-by', ref='relationship--79cfdbac-3e7c-4d47-a85b-b735061b215a')
# ARelation(source='intrusion-set--dc5e2999-ca1a-47d4-8d12-a6984b138a1b', target='intrusion-set--899ce53f-13a0-479b-a0e4-67d46e241542', description='', type='revoked-by', ref='relationship--75f8b97d-73fc-4ba1-8d29-e5d81a929b4f')
# ARelation(source='attack-pattern--10d5f3b7-6be6-4da5-9a77-0f1e2bbfcc44', target='attack-pattern--791481f8-e96a-41be-b089-a088763083d4', description='', type='revoked-by', ref='relationship--c93632b4-0a7a-4492-a0e2-d57cffe7ff64')
# ARelation(source='attack-pattern--10d5f3b7-6be6-4da5-9a77-0f1e2bbfcc44', target='attack-pattern--791481f8-e96a-41be-b089-a088763083d4', description='', type='revoked-by', ref='relationship--53accf9e-5c74-4c3a-bcec-8805f3517ec9')

# %%
relations = []
for rel in relations_index:
    # Groups use techniques 
    if 'intrusion-set' in rel.source and 'attack-pattern' in rel.target and rel.type == 'uses':
        try:
            source_id = groups_id_index[rel.source]
            target_id = techniques_id_index[rel.target]
            relations.append((source_id, target_id, rel.type))
        except: pass

# %%
for obj in attack['objects']:
    if obj['id'] == 'course-of-action--beb45abb-11e8-4aef-9778-1f9ac249784f':
        print(get_technique_id(obj['external_references']))
        print(obj)
# Out:
# T1088
# {'object_marking_refs': ['marking-definition--fa42a846-8d90-4e51-bc29-71d5b4802168'], 'type': 'course-of-action', 'name': 'Bypass User Account Control Mitigation', 'description': 'Remove users from the local administrator group on systems. Although UAC bypass techniques exist, it is still prudent to use the highest enforcement level for UAC when possible and mitigate bypass opportunities that exist with techniques such as [DLL Search Order Hijacking](https://attack.mitre.org/techniques/T1038). \n\nCheck for common UAC bypass weaknesses on Windows systems to be aware of the risk posture and address issues where appropriate. (Citation: Github UACMe)', 'x_mitre_version': '1.0', 'modified': '2019-07-24T14:13:23.637Z', 'created': '2018-10-17T00:14:20.652Z', 'external_references': [{'url': 'https://attack.mitre.org/mitigations/T1088', 'external_id': 'T1088', 'source_name': 'mitre-attack'}, {'url': 'https://github.com/hfiref0x/UACME', 'description': 'UACME Project. (2016, June 16). UACMe. Retrieved July 26, 2016.', 'source_name': 'Github UACMe'}], 'x_mitre_deprecated': True, 'id': 'course-of-action--beb45abb-11e8-4aef-9778-1f9ac249784f', 'created_by_ref': 'identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5', 'spec_version': '2.1', 'x_mitre_attack_spec_version': '2.1.0', 'x_mitre_domains': ['enterprise-attack'], 'x_mitre_modified_by_ref': 'identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5'}

# %%
a
# Out:
# 1

# %%
class Attack:
    
    @staticmethod
    def get_id(references):
        for ref in references:
            if ref['source_name'] == 'mitre-attack':
                return ref['external_id']
        return None

    def __init__(self):
        self.load_config()                         # creates self.cfg
        self.download_attack(self.cfg.attack_data) # creates self.attack
        self.collect_objects()                     # creates self.collections
        self.parse_techniques()
        self.parse_groups()
        self.parse_relations()

    def load_config(self, filename='config.json'):
        with open(filename, 'r') as file:
            data = SimpleNamespace(**loads(file.read()))
            file.close()
        self.cfg = data

    def download_attack(self, url):
        response = get(url)
        if response.ok:
            self.attack = response.json()

    def collect_objects(self):
        self.collections = {}
        for obj in self.attack['objects']:
            tp = obj['type']
            if tp in self.collections:
                self.collections[tp].append(obj)
            else:
                self.collections.update({
                    tp: [obj]
                })

    def parse_techniques(self):
        self.techniques = {}
        self.techniques_list = []
        for obj in self.collections['attack-pattern']:

            if 'revoked' in obj and obj['revoked']: continue
            if 'x-mitre-deprecated' in obj and obj['x-mitre-deprecated']: continue

            id = Attack.get_id(obj['external_references'])

            tactics = []
            for tac in obj['kill_chain_phases']:
                if tac['kill_chain_name'] == 'mitre-attack':
                    tactics.append(
                        tac['phase_name']
                    )

            defense = []
            if 'x_mitre_defense_bypassed' in obj and obj['x_mitre_defense_bypassed']:
                defense = obj['x_mitre_defense_bypassed']

            permissions = []
            if 'x_mitre_permissions_required' in obj and obj['x_mitre_permissions_required']:
                permissions = obj['x_mitre_permissions_required']

            tech = {
                'name': obj['name'],
                'platforms': obj['x_mitre_platforms'],
                'permissions_required': permissions,
                'defenses_bypassed': defense,
                'description': obj['description'],
                'detection': obj['x_mitre_detection'],
                'tactics': tactics,
                'id': id,
                'ref': obj['id']
            }

            atech = ATechnique(**tech)
            self.techniques.update({
                id: atech
            })
            self.techniques_list.append(atech)
            
    def parse_groups(self):
        self.groups_list = []
        self.groups = {}
        for obj in self.collections['intrusion-set']:

            if 'revoked' in obj and obj['revoked']: continue
            if 'x-mitre-deprecated' in obj and obj['x-mitre-deprecated']: continue
            
            id = Attack.get_id(obj['external_references'])

            grp = {
                    'name': obj['name'],
                    'id': id,
                    'ref': obj['id'],
                    'description': obj['description'],
                    'aliases': obj['aliases']
                }

            agrp = AGroup(**grp)
            self.groups_list.append(agrp)
            self.groups.update({
                id: agrp
            })
        return groups
    
    def parse_relations(self):
        self.relations = []
        for rel in self.collections['relationship']:
            data = {
                'source' : rel['source_ref'],
                'target' : rel['target_ref'],
                'description': rel.get('description', ''),
                'type': rel['relationship_type'],
                'ref': rel['id']
            }
            
            src_type = data['source'].split('--')[0]
            trg_type = data['target'].split('--')[0]
            
            src_id = None
            trg_id = None
            
            for obj in self.collections[src_type]:
                if obj['id'] == data['source']:
                    if 'external_references' in obj:
                        src_id = Attack.get_id(obj['external_references'])

            for obj in self.collections[trg_type]:
                if obj['id'] == data['target']:
                    if 'external_references' in obj:
                        trg_id = Attack.get_id(obj['external_references'])
            
            data.update({
                'src': src_id, 'trg': trg_id
            })
            
            self.relations.append(
                ARelation(**data)
            )

# %%
a = Attack()

# %%
from attack import AGroup, ARelation, ATechnique, Attack

# %%
a = Attack()

# %%
a.collections.keys()
# Out:
# dict_keys(['x-mitre-collection', 'attack-pattern', 'relationship', 'course-of-action', 'identity', 'intrusion-set', 'malware', 'tool', 'x-mitre-tactic', 'x-mitre-matrix', 'x-mitre-data-source', 'x-mitre-data-component', 'marking-definition'])
